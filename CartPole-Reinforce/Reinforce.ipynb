# %%
from Reinforce import reinforce, Policy
import gymnasium as gym
import torch.optim as optim

env = gym.make('CartPole-v1')

policy = Policy().to("cpu")
optimizer = optim.Adam(policy.parameters(), lr=1e-2)
scores = reinforce(policy, env, optimizer)
# Out:
# Episode 100	Average Score: 29.04
# Episode 200	Average Score: 58.88
# Episode 300	Average Score: 53.13
# Episode 400	Average Score: 60.90
# Episode 500	Average Score: 55.68
# Episode 600	Average Score: 107.76
# Episode 700	Average Score: 62.22
# Episode 800	Average Score: 65.29
# Episode 900	Average Score: 169.10
# Episode 1000	Average Score: 129.48
# Episode 1100	Average Score: 120.49
# Episode 1200	Average Score: 114.62
# Episode 1300	Average Score: 62.60
# Episode 1400	Average Score: 69.61
# Episode 1500	Average Score: 149.52
# Environment solved in 1454 episodes!	Average Score: 195.09

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
